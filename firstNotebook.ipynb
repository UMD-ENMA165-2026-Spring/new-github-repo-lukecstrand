# %% [markdown]
# # New Notebook for ENMA65
#
#
# [**Warning**]
# > The directory **jupyter_git-lukecstrand** is on my Documents path through **C:\Users\lukec\Documents\ENMA165**, so make sure to **cd** into **"Users"** and not diectly into **"Documents"** from the root to avoid OneDrive.
#
# **Now adding a change to test the *commit* fuction.**

# %% [markdown]
# ### Practice with LaTeX formatting:
# #### Finding the cross product between two vectors in $\mathbb{R}^3$
# $\vec{a} \times \vec{b} $ For $\vec{a} = \langle x_a , y_a, z_a \rangle$ and $\vec{b} = \langle x_b , y_b, z_b \rangle$
# $$ \begin{vmatrix} \hat{i} & \hat{j} & \hat{k} \\ x_a & y_a & z_a \\ x_2 & y_b & z_b \end{vmatrix} = i \begin{vmatrix} y_a & z_a \\ y_b & z_b \end{vmatrix} - j \begin{vmatrix} x_a & z_a \\ x_b & z_b \end{vmatrix} + z \begin{vmatrix} x_a & y_a \\ x_b & y_b \end{vmatrix}$$
# $$= \langle a, b, c \rangle$$
# > This is pretty cool, I never knew that Jupyter Lab's markdown supported LaTeX until the example from lecture. I will definitly start using Jupyter markdown for Latex docs. This is so much easier than using \documentclass and all that other stuff

# %%
import math
import numpy as np

# Set up arrays
dimensions = ['i', 'j', 'k']
v1 = []
v2 = []
print('Cross Product Calculator\n')
print('Enter values for vector A:')
for i in range (3):
        value = float(input(f'Enter value for {dimensions[i]}: '))
        v1.append(value)
print('Enter values for vector B:')
for i in range (3):
        value = float(input(f'Enter value for {dimensions[i]}: '))
        v2.append(value)
print(f'Cross product: {np.cross(v1, v2)}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import math
# ----> 2 import numpy as np
#       4 # Set up arrays
#       5 dimensions = ['i', 'j', 'k']
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# Adding this cell to seeif git marks it as a change, now adding moree because its not marking changes
